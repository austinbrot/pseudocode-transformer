# %%
from google.colab import drive
from os.path import join
ROOT = "/content/drive"
drive.mount(ROOT, force_remount=True)
# Out:
# Mounted at /content/drive

# %%
MY_GOOGLE_DRIVE_PATH = 'My Drive/CS224N_FinalProject'
GIT_REPOSITORY = "austinbrot/pseudocode-transformer"
PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)
# !mkdir "{PROJECT_PATH}"
# GIT_TOKEN = 'N/A'
# GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + "/" + GIT_REPOSITORY + ".git"
# print("GIT PATH: ", GIT_PATH)
# %cd "{PROJECT_PATH}"
# !git clone "{GIT_PATH}"
# %cd "pseudocode-transformer"
# !git branch
# Out:
# /content/drive/My Drive/CS224N_FinalProject
# GIT PATH:  https://45e0bdc6d4940a5c62db4dd02c8d26b0092f1c9e@github.com//austinbrot/pseudocode-transformer.git
# /content/drive/My Drive/CS224N_FinalProject
# /content/drive/My Drive/CS224N_FinalProject/pseudocode-transformer
# * main

# %%
git config --global user.email "nazliugur.koyluoglu@gmail.com"
git config --global user.name "nukoyluoglu"
# Out:
#   File "<ipython-input-9-92941ca218fb>", line 1
#     git config --global user.email "nazliugur.koyluoglu@gmail.com"
#              ^
# SyntaxError: invalid syntax

# %%
# !pip install transformers
# !pip install cython
# !pip install tqdm

# %%
import matplotlib.pyplot as plt
import numpy
import torch
import transformers
from transformers import EncoderDecoderModel

# %%
# !git add .

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	new file:   CS224N - Final Project.ipynb

# %%
# !git commit -m "Re-upload Google Colab"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@72e34ab74401.(none)')

# %%
# !git push origin
# Out:
# Everything up-to-date
